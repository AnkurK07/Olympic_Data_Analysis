# %% [markdown]
# # Olympic Data Analysis
# ![image.png](attachment:image.png)

# %%
'''Working Library'''
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:/Users/ANKUR KUMAR/Data Science/Projects/Analysis/Olympic Data Analysis/athlete_events.csv\athlete_events.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14000\1949541556.py in <module>
# ----> 1 df = pd.read_csv("C:/Users/ANKUR KUMAR/Data Science/Projects/Analysis/Olympic Data Analysis/athlete_events.csv\athlete_events.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
